# %%
import pandas as pd
s=pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([100,200,300],
            index=['A','B','C'])
print(s)
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
data={
    'maths':90,
    'physics':80,
    'chemistry':88
}
s=pd.Series(data)
print(s)
# Out:
# maths        90
# physics      80
# chemistry    88
# dtype: int64

# %%
s=pd.Series([10,20,30,40])
print(s[0])
# Out:
# 10

# %%
s=pd.Series([100,200,300],
            index=['A','B','C'])
print(s['B'])
# Out:
# 200

# %%
print(s[['A','C']])
# Out:
# A    100
# C    300
# dtype: int64

# %%
print(s.size)
# Out:
# 3

# %%
print(s.shape)
# Out:
# (3,)

# %%
print(s.dtype)
# Out:
# int64

# %%
s=pd.Series([10,20,30,40])
print(s+10)
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# dtype: int64

# %%
print(s*2)
# Out:
# 0    20
# 1    40
# 2    60
# 3    80
# dtype: int64

# %%
print("Sum =",s.sum())
print("Mean =",s.mean())
print("Maximum =",s.max())
print("Minimum =",s.min())
# Out:
# Sum = 100
# Mean = 25.0
# Maximum = 40
# Minimum = 10

# %%
import pandas as pd
data={
    'RollNo':[101,102,103],
'Name':['Arun','Priya','Rahul'],
'Marks':[85,90,78]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    RollNo   Name  Marks
# 0     101   Arun     85
# 1     102  Priya     90
# 2     103  Rahul     78

# %%
df=pd.DataFrame(data,
                index=['A','B','C'])
print(df)
# Out:
#    RollNo   Name  Marks
# A     101   Arun     85
# B     102  Priya     90
# C     103  Rahul     78

# %%
print(df.columns)
# Out:
# Index(['RollNo', 'Name', 'Marks'], dtype='object')

# %%
print(df.index)
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
print(df.dtypes)
# Out:
# RollNo     int64
# Name      object
# Marks      int64
# dtype: object

# %%
print(df[['Name','Marks']])
# Out:
#     Name  Marks
# A   Arun     85
# B  Priya     90
# C  Rahul     78

# %%
print(df['Name'])
# Out:
# A     Arun
# B    Priya
# C    Rahul
# Name: Name, dtype: object

# %%
print(df.loc['A'])
# Out:
# RollNo     101
# Name      Arun
# Marks       85
# Name: A, dtype: object

# %%
print(df.loc[['A','C']])
# Out:
#    RollNo   Name  Marks
# A     101   Arun     85
# C     103  Rahul     78

# %%
print(df.iloc[1])
# Out:
# RollNo      102
# Name      Priya
# Marks        90
# Name: B, dtype: object

# %%
print(df.iloc[[0,2]])
# Out:
#    RollNo   Name  Marks
# A     101   Arun     85
# C     103  Rahul     78

# %%
print(df.iloc[0:2,1:3])
# Out:
#     Name  Marks
# A   Arun     85
# B  Priya     90

# %%
df['Grade']=['A','A+','B']
print(df)
# Out:
#    RollNo   Name  Marks Grade
# A     101   Arun     85     A
# B     102  Priya     90    A+
# C     103  Rahul     78     B

# %%
df['Marks']=df['Marks']+5
print(df)
# Out:
#    RollNo   Name  Marks
# 0     101   Arun    100
# 1     102  Priya    105
# 2     103  Rahul     93

# %%
df.drop('Grade',
        axis=1,
        inplace=true)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 df.drop('Grade',
#       3         axis=1,
#       4         inplace=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
print(df)
# Out:
#    RollNo   Name  Marks
# 0     101   Arun     95
# 1     102  Priya    100
# 2     103  Rahul     88

# %%
print(df['Marks'].sum())
# Out:
# 283

# %%
print(df['Marks'].mean())
print(df['Marks'].max())
# Out:
# 99.33333333333333
# 105

# %%
print(df['Marks'].min())
# Out:
# 93

# %%
df.sort_values('Marks')
# Out:
#    RollNo   Name  Marks
# 2     103  Rahul     93
# 0     101   Arun    100
# 1     102  Priya    105

# %%
df.sort_values('Marks',
               ascending=False)
# Out:
#    RollNo   Name  Marks
# 1     102  Priya    105
# 0     101   Arun    100
# 2     103  Rahul     93

# %%
import pandas as pd
data={
    'RollNo':[101,102,103],
'Name':['Arun','Priya','Rahul'],
'Marks':[85,90,78]
}
df=pd.DataFrame(data)
df.sort_values('Marks',
               ascending=True)
# Out:
#    RollNo   Name  Marks
# 2     103  Rahul     78
# 0     101   Arun     85
# 1     102  Priya     90

# %%
print(df[df['Marks']<90])
# Out:
#    RollNo   Name  Marks
# 0     101   Arun     85
# 2     103  Rahul     78

# %%
df.head()
# Out:
#    RollNo   Name  Marks
# 0     101   Arun     85
# 1     102  Priya     90
# 2     103  Rahul     78

# %%
data={
    'RollNo':[101,102,103,104,105,106,107,108,109,110],
'Name':['Arun','Priya','Rahul','Sandy','Anbu','Deena','Raj','Pranav','Mani','Ram'],
'Marks':[85,90,78,45,66,77,88,99,56,77]
}
df=pd.DataFrame(data)
df.tail()
# Out:
#    RollNo    Name  Marks
# 5     106   Deena     77
# 6     107     Raj     88
# 7     108  Pranav     99
# 8     109    Mani     56
# 9     110     Ram     77

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RollNo  10 non-null     int64
#  1   Name    10 non-null     object
#  2   Marks   10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#           RollNo      Marks
# count   10.00000  10.000000
# mean   105.50000  76.100000
# std      3.02765  16.387326
# min    101.00000  45.000000
# 25%    103.25000  68.750000
# 50%    105.50000  77.500000
# 75%    107.75000  87.250000
# max    110.00000  99.000000

# %%
data={
    'RollNo':[101,102,103,104,105,106,107,108,109,110],
'Name':['Arun','Priya','Rahul','Sandy','Anbu','Deena','Raj','Pranav','Mani','Ram'],
'Dept':['CS','DS','AI','Hrm','Ca','Bcom','ML','BCA','MCA','BBA'],
'Cgpa':[7,8,9,9,6,7,8,8,9,8]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    RollNo    Name  Dept  Cgpa
# 0     101    Arun    CS     7
# 1     102   Priya    DS     8
# 2     103   Rahul    AI     9
# 3     104   Sandy   Hrm     9
# 4     105    Anbu    Ca     6
# 5     106   Deena  Bcom     7
# 6     107     Raj    ML     8
# 7     108  Pranav   BCA     8
# 8     109    Mani   MCA     9
# 9     110     Ram   BBA     8

# %%
data={
    'RollNo':[101,102,103,104,105,106,107,108,109,110],
'Name':['Arun','Priya','Rahul','Sandy','Anbu','Deena','Raj','Pranav','Mani','Ram'],
'Marks':[85,90,78,45,66,77,88,99,56,77]
}
df=pd.DataFrame(data)
print(df['Marks'].sum())
print(df['Marks'].mean())
print(df['Marks'].max())
print(df['Marks'].min())
# Out:
# 761
# 76.1
# 99
# 45

# %%
data={
'Name':['Arun','Priya','Rahul','Sandy','Anbu'],
'Salary':[85000,50000,38000,48000,55000]
}
df=pd.DataFrame(data)
print(df[df['Salary']>40000])
# Out:
#     Name  Salary
# 0   Arun   85000
# 1  Priya   50000
# 3  Sandy   48000
# 4   Anbu   55000

# %%
df.sort_values('Salary',
               ascending=True)
# Out:
#     Name  Salary
# 2  Rahul   38000
# 3  Sandy   48000
# 1  Priya   50000
# 4   Anbu   55000
# 0   Arun   85000

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Ibscai29.DGVC-MCA\Documents\students.csv.csv")
print(df)
# Out:
#    RollNo   Name Department  Marks
# 0     101   Arun        CSE     85
# 1     102  Priya         AI     92
# 2     103  Rahul         IT     78
# 3     104  Divya        CSE     88

# %%
print(df.size)
# Out:
# 16

# %%
print(df.shape)
# Out:
# (4, 4)

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    RollNo   Name Department  Marks
# 0     101   Arun        CSE     85
# 1     102  Priya         AI     92
# 2     103  Rahul         IT     78
# 3     104  Divya        CSE     88>

# %%
df.head(2)
# Out:
#    RollNo   Name Department  Marks
# 0     101   Arun        CSE     85
# 1     102  Priya         AI     92

# %%
df.tail(2)
# Out:
#    RollNo   Name Department  Marks
# 2     103  Rahul         IT     78
# 3     104  Divya        CSE     88

# %%
df.dtypes
# Out:
# RollNo         int64
# Name          object
# Department    object
# Marks          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RollNo      4 non-null      int64
#  1   Name        4 non-null      object
#  2   Department  4 non-null      object
#  3   Marks       4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
print(df.loc(1))

# %%
print(df.iloc[2])
# Out:
# RollNo          103
# Name          Rahul
# Department       IT
# Marks            78
# Name: 2, dtype: object

# %%
print(df[df["Marks"]>80])
# Out:
#    RollNo   Name Department  Marks
# 0     101   Arun        CSE     85
# 1     102  Priya         AI     92
# 3     104  Divya        CSE     88

# %%
df["Grade"]=["A","A","B","A"]
print(df)
# Out:
#    RollNo   Name Department  Marks Grade
# 0     101   Arun        CSE     85     A
# 1     102  Priya         AI     92     A
# 2     103  Rahul         IT     78     B
# 3     104  Divya        CSE     88     A

# %%
df["Marks"]=df["Marks"]+5
print(df)
# Out:
#    RollNo   Name Department  Marks Grade
# 0     101   Arun        CSE     90     A
# 1     102  Priya         AI     97     A
# 2     103  Rahul         IT     83     B
# 3     104  Divya        CSE     93     A
