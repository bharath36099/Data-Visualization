# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]
x1=[1,2,3,4]
y1=[4,6,3,10]
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.xlim(1,10)
plt.ylim(5,15)
plt.title("Line Plot Example")
plt.plot(x,y,label="Line-1",color='grey',linestyle='dashdot',linewidth=3,marker='D',markerfacecolor='green',markersize=12)
plt.plot(x1,y1,label="Line-2")
plt.legend()
plt.savefig("sampledv.png")
plt.show()

# %%
import matplotlib.pyplot as plt

rollno=[101,102,103,104,105]
marks=[80,75,62,93,74]
plt.xlabel("RollNo")
plt.ylabel("Marks")
plt.xlim(100,110)
plt.ylim(50,100)
plt.title("Students RollNo Marks")
plt.plot(rollno,marks)
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Ibscai29.DGVC-MCA\Documents\iris.csvpd.csv")
x=df["sepal_length"]
y=df["sepal_width"]
x1=df["petal_length"]
y1=df["petal_width"]
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.xlim(100,110)
plt.ylim(50,100)
plt.title("Iris")
plt.plot(x,y,label="Line-1",color='grey',linestyle='dashdot',linewidth=3,marker='D',markerfacecolor='green',markersize=12)
plt.plot(x1,y1,label="Line-2")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\Ibscai29.DGVC-MCA\Documents\iris.csvpd.csv")

x = df["sepal_length"]
y = df["sepal_width"]
x1 = df["petal_length"]
y1 = df["petal_width"]

plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.title("Iris")
plt.plot(x, y,label="Line-1",color="grey",linestyle="dashed",linewidth=3,marker="o",markerfacecolor="white",markersize=12)
plt.plot(x1, y1,label="Line-2",color="brown")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
students=["A","B","C","D","E",]
marks=[60,70,80,90,50]
plt.bar(students,marks,color="green",width=0.5,edgecolor="orange",label="Student Marks")
plt.legend()
plt.title("Student Marks in Semester")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
hours=[2,3,4,5,6]
marks=[45,56,87,68,78]
plt.scatter(hours,marks,color="blue",marker="D",s=280,label="Student")

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\Ibscai29.DGVC-MCA\Documents\iris.csvpd.csv")

x = df["sepal_length"][0:5]
y = df["sepal_width"][0:5]
plt.xlabel(x)
plt.ylabel(y)
plt.xlim(0,5)
plt.ylim(0,10)
plt.title("Iris")
plt.bar(x, y,color="brown",width=0.5)
plt.show()
plt.legend()
plt.scatter(x, y,label="Line-1",color="grey",linestyle="dashed",linewidth=3,marker="o")
# Out:
# C:\Users\Ibscai29.DGVC-MCA\AppData\Local\Temp\ipykernel_7964\2412319151.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
marks=[45,50,55,55,60,65,65,70,70,75,80,85]
plt.hist(marks)
# Out:
# (array([1., 1., 2., 1., 0., 2., 2., 1., 1., 1.]),
#  array([45., 49., 53., 57., 61., 65., 69., 73., 77., 81., 85.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['sepal_length'])
# Out:
# (array([ 1.,  1.,  1.,  0.,  5., 32., 39., 40., 22.,  8.]),
#  array([1.  , 1.69, 2.38, 3.07, 3.76, 4.45, 5.14, 5.83, 6.52, 7.21, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
marks = [45,50,55,55,60,65,65,70,70,75,80,85]
series = pd.Series(marks)

# %%
x.plot(kind="density",color="red",linewidth=2,linestyle="--",label="Marks")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.subplot(2,2,1)
x.plot(kind="density")
plt.subplot(2,2,2)
plt.hist(marks)
plt.subplot(2,2,3)
plt.scatter(x,y)
plt.subplot(2,2,4)
plt.bar(x,y)
plt.title("students marks")
plt.suptitle("Students performance analysis")
# Out:
# Text(0.5, 0.98, 'Students performance analysis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\Ibscai29.DGVC-MCA\Documents\foodhub_order.csv")
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time
# count    1898.000000
# mean       24.161749
# std         4.972637
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000

# %%
sns.countplot(data=df,x=df['cuisine_type'])
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.countplot(data=df,x=df['cuisine_type'])
#       2 plt.xticks(rotation=90)
#
# NameError: name 'sns' is not defined
